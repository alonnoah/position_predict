# %%
import requests
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
from sklearn import metrics,preprocessing,svm
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
all_data = pd.read_csv("AllTheData.csv")
clean_data = all_data.copy()
clean_data_2 = all_data.copy()
all_data.columns   # name's of the colums in the daa=ta
# Out:
# Index(['Player', 'Overall Score', 'Height', 'Weight', 'Age', 'Preferred Foot',
#        'Preferred Positions', 'Ball Control', 'Dribbling', 'Marking',
#        'Slide Tackle', 'Stand Tackle', 'Aggression', 'Reactions',
#        'Attack Position', 'Interceptions', 'Vision', 'Composure', 'Crossing',
#        'Short Pass', 'Long Pass', 'Acceleration', 'Stamina', 'Strength',
#        'Balance', 'Sprint Speed', 'Agility', 'Jumping', 'Heading',
#        'Shot Power', 'Finishing', 'Long Shots', 'Curve', 'Free Kick Acc',
#        'Penalties', 'Volleys'],
#       dtype='object')

# %%
all_data.isnull().sum()   # how much rows of Nan we have
# Out:
# Player                 0
# Overall Score          0
# Height                 0
# Weight                 0
# Age                    0
# Preferred Foot         0
# Preferred Positions    0
# Ball Control           0
# Dribbling              0
# Marking                0
# Slide Tackle           0
# Stand Tackle           0
# Aggression             0
# Reactions              0
# Attack Position        0
# Interceptions          0
# Vision                 0
# Composure              0
# Crossing               0
# Short Pass             0
# Long Pass              0
# Acceleration           0
# Stamina                0
# Strength               0
# Balance                0
# Sprint Speed           0
# Agility                0
# Jumping                0
# Heading                0
# Shot Power             0
# Finishing              0
# Long Shots             0
# Curve                  0
# Free Kick Acc          0
# Penalties              0
# Volleys                0
# dtype: int64

# %%
all_data.dropna(axis=0)   #drop all the Nan's row value
# Out:
#                   Player  Overall Score  Height  Weight  Age Preferred Foot  \
# 0           Lionel Messi             93     170      72   34           Left
# 1     Robert Lewandowski             92     185      81   33          Right
# 2          Kylian Mbappé             91     182      73   23          Right
# 3              Jan Oblak             91     188      87   28          Right
# 4        Kevin De Bruyne             91     181      70   30          Right
# ...                  ...            ...     ...     ...  ...            ...
# 5575        Renaud Emond             69     186      73   30          Right
# 5576    William Mendieta             69     179      77   32          Right
# 5577            Glen Rea             69     184      73   27          Right
# 5578      Gustav Engvall             69     184      85   25          Right
# 5579        Callum Elder             69     180      67   26           Left
#
# ...

# %%
all_data.duplicated()   #search for duplicated
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5575    False
# 5576    False
# 5577    False
# 5578    False
# 5579    False
# Length: 5580, dtype: bool

# %%
if(all_data.duplicated().sum()>0):
    all_data.drop_duplicates()

# %%
all_data.info()   #information about the type pf every colum
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5580 entries, 0 to 5579
# Data columns (total 36 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Player               5580 non-null   object
#  1   Overall Score        5580 non-null   int64
#  2   Height               5580 non-null   int64
#  3   Weight               5580 non-null   int64
#  4   Age                  5580 non-null   int64
#  5   Preferred Foot       5580 non-null   object
#  6   Preferred Positions  5580 non-null   object
#  7   Ball Control         5580 non-null   float64
#  8   Dribbling            5580 non-null   float64
#  9   Marking              5580 non-null   float64
#  10  Slide Tackle         5580 non-null   float64
#  11  Stand Tackle         5580 non-null   float64
#  12  Aggression           5580 non-null   float64
#  13  Reactions            5580 non-null   float64
#  14  Attack Position      5580 non-null   float64
# ...

# %%
for ind,pos in enumerate(clean_data['Preferred Positions']):
    if (pos.startswith('LB') or pos.startswith('RB') or pos.startswith('LWB')):
        clean_data.loc[ind, 'Preferred Positions'] = 1
    elif (pos.startswith('SW') or pos.startswith('RWB') or pos.startswith('CB')):
        clean_data.loc[ind, 'Preferred Positions'] = 1
    elif (pos.startswith('CAM') or pos.startswith('CM') or pos.startswith('CDM')):
        clean_data.loc[ind, 'Preferred Positions'] = 2
    elif (pos.startswith('RM') or pos.startswith('LM')):
        clean_data.loc[ind, 'Preferred Positions'] = 2
    elif (pos.startswith('LW') or pos.startswith('LF') or pos.startswith('ST')):
        clean_data.loc[ind, 'Preferred Positions'] = 3
    elif (pos.startswith('CF') or pos.startswith('RF') or pos.startswith('RW')):
        clean_data.loc[ind, 'Preferred Positions'] = 3
    elif(pos.startswith('GK')):
           clean_data.drop(ind, axis=0, inplace=True)

# %%
clean_data['Preferred Foot'].replace({"Right": 0, "Left": 1}, inplace=True)
clean_data.to_csv(r'/Users/user/PycharmProjects/DataLeNetunim/eda_2_data.csv', index=False)

# %%
eda_csv = pd.read_csv('eda_data.csv')
eda_csv
# Out:
#                   Player  Overall Score  Height  Weight  Age  Preferred Foot  \
# 0           Lionel Messi             93     170      72   34               1
# 1     Robert Lewandowski             92     185      81   33               0
# 2          Kylian Mbappé             91     182      73   23               0
# 3        Kevin De Bruyne             91     181      70   30               0
# 4              Neymar Jr             91     175      68   29               0
# ...                  ...            ...     ...     ...  ...             ...
# 5061        Renaud Emond             69     186      73   30               0
# 5062    William Mendieta             69     179      77   32               0
# 5063            Glen Rea             69     184      73   27               0
# 5064      Gustav Engvall             69     184      85   25               0
# 5065        Callum Elder             69     180      67   26               1
#
# ...

# %%
print("Results for our second file (players' positions are determined by the last position)")
# Out:
# Results for our second file (players' positions are determined by the last position)

# %%
for ind,pos in enumerate(clean_data_2['Preferred Positions']):
    if (pos.endswith('LB') or pos.endswith('RB') or pos.endswith('LWB')):
        clean_data_2.loc[ind, 'Preferred Positions'] = 1
    elif (pos.endswith('SW') or pos.endswith('RWB') or pos.endswith('CB')):
        clean_data_2.loc[ind, 'Preferred Positions'] = 1
    elif (pos.endswith('CAM') or pos.endswith('CM') or pos.endswith('CDM')):
        clean_data_2.loc[ind, 'Preferred Positions'] = 2
    elif (pos.endswith('RM') or pos.endswith('LM')):
        clean_data_2.loc[ind, 'Preferred Positions'] = 2
    elif (pos.endswith('LW') or pos.endswith('LF') or pos.endswith('ST')):
        clean_data_2.loc[ind, 'Preferred Positions'] = 3
    elif (pos.endswith('CF') or pos.endswith('RF') or pos.endswith('RW')):
        clean_data_2.loc[ind, 'Preferred Positions'] = 3
    elif(pos.endswith('GK')):
           clean_data_2.drop(ind, axis=0, inplace=True)

# %%
clean_data_2['Preferred Foot'].replace({"Right": 0, "Left": 1}, inplace=True)
clean_data_2.to_csv(r'/Users/user/PycharmProjects/DataLeNetunim/eda_2_data.csv', index=False)

# %%
eda_2_csv = pd.read_csv('eda_2_data.csv')
eda_2_csv
# Out:
#                   Player  Overall Score  Height  Weight  Age  Preferred Foot  \
# 0           Lionel Messi             93     170      72   34               1
# 1     Robert Lewandowski             92     185      81   33               0
# 2          Kylian Mbappé             91     182      73   23               0
# 3        Kevin De Bruyne             91     181      70   30               0
# 4              Neymar Jr             91     175      68   29               0
# ...                  ...            ...     ...     ...  ...             ...
# 5061        Renaud Emond             69     186      73   30               0
# 5062    William Mendieta             69     179      77   32               0
# 5063            Glen Rea             69     184      73   27               0
# 5064      Gustav Engvall             69     184      85   25               0
# 5065        Callum Elder             69     180      67   26               1
#
# ...
